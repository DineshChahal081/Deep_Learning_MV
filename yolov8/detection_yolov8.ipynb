# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp '/content/drive/MyDrive/Aadhaar_card_dataset_for_training.zip' /content/

# %%
# !unzip '/content/Aadhaar_card_dataset_for_training.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Aadhaar_card_dataset_for_training/data/train/images/19b620ad00aeb2885f0f0a1ccb337919_jpg.rf.666a0dbd79700ca0945c19b9ac1b1fe6.jpg
#   inflating: /content/Aadhaar_card_dataset_for_training/data/train/images/19b620ad00aeb2885f0f0a1ccb337919_jpg.rf.6681a9cf05c560ee4a7e2e8be35f71b4.jpg
#   inflating: /content/Aadhaar_card_dataset_for_training/data/train/images/19b620ad00aeb2885f0f0a1ccb337919_jpg.rf.686680eeab553667f021b7f411b5f20b.jpg
#   inflating: /content/Aadhaar_card_dataset_for_training/data/train/images/19b620ad00aeb2885f0f0a1ccb337919_jpg.rf.94fb4a64e57c72aee1327663707be67f.jpg
#   inflating: /content/Aadhaar_card_dataset_for_training/data/train/images/19b620ad00aeb2885f0f0a1ccb337919_jpg.rf.9d6cd43257754507a392f8952cef8f8f.jpg
#   inflating: /content/Aadhaar_card_dataset_for_training/data/train/images/19b620ad00aeb2885f0f0a1ccb337919_jpg.rf.a48fb648bc4580b4d7003c27e120a17f.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 10.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo detect train data='/content/Aadhaar_card_dataset_for_training/data.yaml' model=yolov8x.pt epochs=30 imgsz=320 project =' /content/training_results' name = target_roi
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 303MB/s]
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp /content/training_results/target_roi/weights/best.pt "/content/drive/MyDrive/target_roi"

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/target_roi3/medium_best.pt source =/content/IMG-20220119-WA0026.jpg show=True imgsz=320 name=yolov8n_v8_50e_infer1280
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/IMG-20220119-WA0026.jpg: 320x256 2 0s, 1 1, 1 2, 2 3s, 1 4, 412.2ms
# Speed: 1.8ms preprocess, 412.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to runs/detect/yolov8n_v8_50e_infer12808
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !cp -r /content/runs/detect/yolov8n_v8_50e_infer12806/ "/content/drive/MyDrive/test_yolov8m/"

# %%
# !yolo export model=/content/drive/MyDrive/target_roi2/small_best.pt format="openvino" imgsz = 320 half = True
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/target_roi2/small_best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 9, 2100) (21.4 MB)
# requirements: Ultralytics requirement ['openvino>=2023.3'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 131.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 11.5s, installed 1 package: ['openvino>=2023.3']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# OpenVINO: starting export with openvino 2024.0.0-14509-34caeefd078-releases/2024/0...
# OpenVINO: export success ✅ 15.4s, saved as '/content/drive/MyDrive/target_roi2/small_best_openvino_model/' (21.5 MB)
#
# Export complete (17.5s)
# Results saved to /content/drive/MyDrive/target_roi2
# ...
